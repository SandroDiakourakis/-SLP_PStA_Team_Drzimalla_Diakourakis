# %% [markdown]
# Kann man das pooling so anpassen, dass es die ersten Frames der Audiodatei nimmt und die letzten, somit kann man evtl. gut einen Unterschied erkennen.
#
# => pooling = first-last
#     wurde implementiert
#
#
# Nächstes Experiment Hidden Layer wieder anpassen
# auf einen Status von Fabi sprich ( 6, 12, 18) oder ähnlich

# %% [markdown]
# experiment_20251113_130308
# in main
# -  LAYER_FUSION = "weighted" # "concat", "mean", or "weighted"
# - LAYERS = [6, 7, 8, 9, 10]
#
# experiments/experiment_20251113_194636
# in main
# - LAYER_FUSION = "weighted" # "concat", "mean", or "weighted"
# - LAYERS = [6, 9, 12, 15, 18]
#
# nächstes experiment
# in main
# - LAYER_FUSION = "mean" # "concat", "mean", or "weighted"
# - LAYERS = [6, 9, 12, 15, 18]
